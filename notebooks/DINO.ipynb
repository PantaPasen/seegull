# %%
# %reload_ext autoreload
# %autoreload 2

import numpy as np
import pandas as pd

from seegull import get_image_df
from seegull import dino

# %%
# Load the annotations
df = pd.read_csv("../tests/data/images.csv")

# Create a unique ID for each row/annotation
df["id"] = np.arange(len(df))

df
# Out:
#                image_id                                       image_source  \
# 0   2105761973738690856  https://storage.googleapis.com/seegull-test-da...
# 1    357721097128884392  https://storage.googleapis.com/seegull-test-da...
# 2    328325079742791550  https://storage.googleapis.com/seegull-test-da...
# 3   4875697904501717195  https://storage.googleapis.com/seegull-test-da...
# 4   4875697904501717195  https://storage.googleapis.com/seegull-test-da...
# 5   4875697904501717195  https://storage.googleapis.com/seegull-test-da...
# 6   4875697904501717195  https://storage.googleapis.com/seegull-test-da...
# 7   4875697904501717195  https://storage.googleapis.com/seegull-test-da...
# 8   4875697904501717195  https://storage.googleapis.com/seegull-test-da...
# 9    468836346316123269  https://storage.googleapis.com/seegull-test-da...
# 10   468836346316123269  https://storage.googleapis.com/seegull-test-da...
# 11   225696838630806860  https://storage.googleapis.com/seegull-test-da...
# 12   225696838630806860  https://storage.googleapis.com/seegull-test-da...
# 13   471293006637358863  https://storage.googleapis.com/seegull-test-da...
# 14   475762560805920967  https://storage.googleapis.com/seegull-test-da...
# 15  2724008258589670712  https://storage.googleapis.com/seegull-test-da...
# 16  2724008258589670712  https://storage.googleapis.com/seegull-test-da...
# 17  7516759146918185929  https://storage.googleapis.com/seegull-test-da...
# 18  7516759146918185929  https://storage.googleapis.com/seegull-test-da...
# 19  7516759146918185929  https://storage.googleapis.com/seegull-test-da...
# 20  7516759146918185929  https://storage.googleapis.com/seegull-test-da...
#
#     image_height  image_width                          object  \
# 0            900          900                Can/Tin/Cylinder
# 1            900          900             Box/Card/Tray/Crate
# 2            901          901  Flexibles/Bag/Wrapper/Foil/Net
# 3            666          500                         Battery
# 4            666          500                         Battery
# 5            666          500                         Battery
# 6            666          500                         Battery
# 7            666          500                         Battery
# 8            666          500                         Battery
# 9            901          901                          Bottle
# 10           901          901                         Lid/Cap
# 11           900          900                          Bottle
# 12           900          900                         Lid/Cap
# 13           900          900             Box/Card/Tray/Crate
# 14           900          900  Flexibles/Bag/Wrapper/Foil/Net
# 15           901          901                         Aerosol
# 16           901          901                         Lid/Cap
# 17           666          500                         Battery
# 18           666          500                         Battery
# 19           666          500                         Battery
# 20           666          500                         Battery
#
#                                material        brand     x1     y1     x2  \
# 0                                 Metal  old jamaica  284.0   74.0  674.0
# 1   Fiber - Cardboard / Paper Packaging   björn borg  222.0  206.0  633.0
# 2                        Plastic - Soft  almo nature  196.0   49.0  710.0
# 3                       Hazardous Waste      unknown  263.0  255.0  376.0
# 4                       Hazardous Waste      unknown   71.0  248.0  176.0
# 5                       Hazardous Waste      unknown  166.0  270.0  265.0
# 6                       Hazardous Waste    energizer  286.0  306.0  389.0
# 7                       Hazardous Waste      unknown  113.0  299.0  185.0
# 8                       Hazardous Waste      unknown  206.0  328.0  298.0
# 9                        Plastic - Hard    smarteyes  340.0   35.0  577.0
# 10                            Composite    smarteyes  396.0   35.0  535.0
# 11                       Plastic - Hard      hydrate  326.0   67.0  578.0
# 12                       Plastic - Hard      hydrate  370.0   71.0  517.0
# 13  Fiber - Cardboard / Paper Packaging  tgi fridays  113.0   69.0  761.0
# 14                       Plastic - Soft         asda  139.0  360.0  803.0
# 15                                Metal         1001  328.0    0.0  558.0
# 16                       Plastic - Hard         1001  359.0    0.0  559.0
# 17                      Hazardous Waste        varta  204.0  268.0  318.0
# 18                      Hazardous Waste    andersson  253.0  317.0  370.0
# 19                      Hazardous Waste          NaN  127.0  240.0  238.0
# 20                      Hazardous Waste      unknown  120.0  353.0  243.0
#
#        y2  id
# 0   780.0   0
# 1   726.0   1
# 2   788.0   2
# 3   305.0   3
# 4   357.0   4
# 5   347.0   5
# 6   384.0   6
# 7   427.0   7
# 8   417.0   8
# 9   856.0   9
# 10  258.0  10
# 11  822.0  11
# 12  125.0  12
# 13  781.0  13
# 14  562.0  14
# 15  901.0  15
# 16  181.0  16
# 17  333.0  17
# 18  376.0  18
# 19  323.0  19
# 20  402.0  20

# %%
# Get the embeddings
dinov2 = dino.DINOv2()
df["embeddings"] = dinov2.embeddings(df=df)
df
# Out:
# loading images: 100%|██████████| 21/21 [00:00<00:00, 24.42it/s]
# 100%|██████████| 1/1 [00:04<00:00,  4.44s/it]
#                image_id                                       image_source  \
# 0   2105761973738690856  https://storage.googleapis.com/seegull-test-da...
# 1    357721097128884392  https://storage.googleapis.com/seegull-test-da...
# 2    328325079742791550  https://storage.googleapis.com/seegull-test-da...
# 3   4875697904501717195  https://storage.googleapis.com/seegull-test-da...
# 4   4875697904501717195  https://storage.googleapis.com/seegull-test-da...
# 5   4875697904501717195  https://storage.googleapis.com/seegull-test-da...
# 6   4875697904501717195  https://storage.googleapis.com/seegull-test-da...
# 7   4875697904501717195  https://storage.googleapis.com/seegull-test-da...
# 8   4875697904501717195  https://storage.googleapis.com/seegull-test-da...
# 9    468836346316123269  https://storage.googleapis.com/seegull-test-da...
# 10   468836346316123269  https://storage.googleapis.com/seegull-test-da...
# 11   225696838630806860  https://storage.googleapis.com/seegull-test-da...
# 12   225696838630806860  https://storage.googleapis.com/seegull-test-da...
# 13   471293006637358863  https://storage.googleapis.com/seegull-test-da...
# 14   475762560805920967  https://storage.googleapis.com/seegull-test-da...
# 15  2724008258589670712  https://storage.googleapis.com/seegull-test-da...
# 16  2724008258589670712  https://storage.googleapis.com/seegull-test-da...
# 17  7516759146918185929  https://storage.googleapis.com/seegull-test-da...
# 18  7516759146918185929  https://storage.googleapis.com/seegull-test-da...
# 19  7516759146918185929  https://storage.googleapis.com/seegull-test-da...
# 20  7516759146918185929  https://storage.googleapis.com/seegull-test-da...
#
#     image_height  image_width                          object  \
# 0            900          900                Can/Tin/Cylinder
# 1            900          900             Box/Card/Tray/Crate
# 2            901          901  Flexibles/Bag/Wrapper/Foil/Net
# 3            666          500                         Battery
# 4            666          500                         Battery
# 5            666          500                         Battery
# 6            666          500                         Battery
# 7            666          500                         Battery
# 8            666          500                         Battery
# 9            901          901                          Bottle
# 10           901          901                         Lid/Cap
# 11           900          900                          Bottle
# 12           900          900                         Lid/Cap
# 13           900          900             Box/Card/Tray/Crate
# 14           900          900  Flexibles/Bag/Wrapper/Foil/Net
# 15           901          901                         Aerosol
# 16           901          901                         Lid/Cap
# 17           666          500                         Battery
# 18           666          500                         Battery
# 19           666          500                         Battery
# 20           666          500                         Battery
#
#                                material        brand     x1     y1     x2  \
# 0                                 Metal  old jamaica  284.0   74.0  674.0
# 1   Fiber - Cardboard / Paper Packaging   björn borg  222.0  206.0  633.0
# 2                        Plastic - Soft  almo nature  196.0   49.0  710.0
# 3                       Hazardous Waste      unknown  263.0  255.0  376.0
# 4                       Hazardous Waste      unknown   71.0  248.0  176.0
# 5                       Hazardous Waste      unknown  166.0  270.0  265.0
# 6                       Hazardous Waste    energizer  286.0  306.0  389.0
# 7                       Hazardous Waste      unknown  113.0  299.0  185.0
# 8                       Hazardous Waste      unknown  206.0  328.0  298.0
# 9                        Plastic - Hard    smarteyes  340.0   35.0  577.0
# 10                            Composite    smarteyes  396.0   35.0  535.0
# 11                       Plastic - Hard      hydrate  326.0   67.0  578.0
# 12                       Plastic - Hard      hydrate  370.0   71.0  517.0
# 13  Fiber - Cardboard / Paper Packaging  tgi fridays  113.0   69.0  761.0
# 14                       Plastic - Soft         asda  139.0  360.0  803.0
# 15                                Metal         1001  328.0    0.0  558.0
# 16                       Plastic - Hard         1001  359.0    0.0  559.0
# 17                      Hazardous Waste        varta  204.0  268.0  318.0
# 18                      Hazardous Waste    andersson  253.0  317.0  370.0
# 19                      Hazardous Waste          NaN  127.0  240.0  238.0
# 20                      Hazardous Waste      unknown  120.0  353.0  243.0
#
#        y2  id                                         embeddings
# 0   780.0   0  [-2.7657711505889893, -0.6070233583450317, 3.0...
# 1   726.0   1  [-0.2816886007785797, 0.7678671479225159, -2.6...
# 2   788.0   2  [2.787356376647949, -4.27956485748291, 1.89843...
# 3   305.0   3  [2.116034507751465, -0.05328032001852989, -0.4...
# 4   357.0   4  [0.6707794070243835, 0.9232046008110046, 0.738...
# 5   347.0   5  [4.105702877044678, -1.3100790977478027, 3.557...
# 6   384.0   6  [5.4399237632751465, -0.8412368893623352, 5.07...
# 7   427.0   7  [1.3370554447174072, -0.02653452195227146, 0.1...
# 8   417.0   8  [2.3538990020751953, -0.09903288632631302, 3.3...
# 9   856.0   9  [-0.8826137185096741, 0.3607774078845978, 1.21...
# 10  258.0  10  [2.0883827209472656, 2.165667772293091, -2.738...
# 11  822.0  11  [-3.1158530712127686, -1.3709971904754639, 4.4...
# 12  125.0  12  [2.311300754547119, 2.049203872680664, 1.82329...
# 13  781.0  13  [-4.31397008895874, -0.12732109427452087, -2.6...
# 14  562.0  14  [2.7972941398620605, -1.695876955986023, 2.234...
# 15  901.0  15  [-1.2992799282073975, 0.7163777351379395, 6.10...
# 16  181.0  16  [3.4468326568603516, -0.4432370960712433, 4.89...
# 17  333.0  17  [2.0938727855682373, -1.5826244354248047, 3.24...
# 18  376.0  18  [2.657822370529175, -1.9625095129013062, 1.705...
# 19  323.0  19  [2.2801146507263184, -0.11393669247627258, 4.6...
# 20  402.0  20  [4.923325538635254, -1.1407090425491333, -4.88...

# %%
# Initialize a KNNSearch object with this model and data
knn = dinov2.knn(df, n_neighbors=5)

# %%
# Search for a battery (The last row in our DataFrame)
# The first result is the object itself
for dist, row in knn.search(df.tail(1)["embeddings"])[0]:
    print(dist, row.object)
# Out:
# 1.3486991523486091e-06 Battery
# 42.3069804905232 Battery
# 45.27193289895602 Battery
# 47.5194413377659 Battery
# 48.414388729549955 Battery

# %%
# Predict the object type by aggregating the search results
knn.predict(df.tail(1), "object", index_col="id")
# Out:
#      object  object_conf
# 20  Battery          1.0

# %%
# Compare the predictions for all rows vs. the ground truth.
# The results are not good because batteries are the only object that we have
# many examples of in this data.
knn.evaluate_predict(df, "object", index_col="id")[
    ["object", "object_pred", "object_conf", "object_correct"]
]
# Out:
#                             object                     object_pred  \
# 0                 Can/Tin/Cylinder                          Bottle
# 1              Box/Card/Tray/Crate                         Battery
# 2   Flexibles/Bag/Wrapper/Foil/Net  Flexibles/Bag/Wrapper/Foil/Net
# 3                          Battery                         Battery
# 4                          Battery                         Battery
# 5                          Battery                         Battery
# 6                          Battery                         Battery
# 7                          Battery                         Battery
# 8                          Battery                         Battery
# 9                           Bottle                         Battery
# 10                         Lid/Cap                         Battery
# 11                          Bottle                         Lid/Cap
# 12                         Lid/Cap                         Lid/Cap
# 13             Box/Card/Tray/Crate                         Battery
# 14  Flexibles/Bag/Wrapper/Foil/Net                         Aerosol
# 15                         Aerosol                Can/Tin/Cylinder
# 16                         Lid/Cap                         Aerosol
# 17                         Battery                         Battery
# 18                         Battery                         Battery
# 19                         Battery                         Battery
# 20                         Battery                         Battery
#
#     object_conf  object_correct
# 0      0.469962           False
# 1      0.484675           False
# 2      0.261325            True
# 3      1.000000            True
# 4      1.000000            True
# 5      1.000000            True
# 6      1.000000            True
# 7      1.000000            True
# 8      1.000000            True
# 9      0.710895           False
# 10     0.458459           False
# 11     0.473287           False
# 12     0.525499            True
# 13     0.502496           False
# 14     0.262657           False
# 15     0.269627           False
# 16     0.281257           False
# 17     1.000000            True
# 18     1.000000            True
# 19     1.000000            True
# 20     1.000000            True
